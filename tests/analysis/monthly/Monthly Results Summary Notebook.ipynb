# %% [markdown]
# ## Exploration of Monthly Savings Results Summary Statistics

# %%
import pandas as pd
# Out:
# /Users/matthewgee/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
oee_summary = pd.read_csv("monthly_billing_analysis_savings_summary_OpenEEMeter.csv")
                          
#savvy_summary
#dnv_summary

# %%
oee_summary
# Out:
#    Total number of sites included in first-stage estimation          2808
# 0   Total number of sites with cumulative gross sa...         2761.000000
# 1   Total number of sites with normal year annuali...         2761.000000
# 2   Total number of sites with current year annual...         2761.000000
# 3                        Min cumulative gross savings       -23407.526879
# 4                        Max cumulative gross savings        38290.605464
# 5                    Average cumulative gross savings          610.527803
# 6      10th percentile value cumulative gross savings        -2192.889464
# 7      20th percentile value cumulative gross savings         -899.847381
# 8      30th percentile value cumulative gross savings         -266.140156
# 9      40th percentile value cumulative gross savings           76.859991
# 10     50th percentile value cumulative gross savings          357.701595
# 11     60th percentile value cumulative gross savings          754.670371
# ...
